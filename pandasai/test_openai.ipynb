# %%
from pandasai import SmartDataframe
from pandasai.llm import OpenAI
from dotenv import load_dotenv
from pandasai.helpers.openai_info import get_openai_callback

# %%
load_dotenv('../keys.env')
# Out:
# True

# %%
llm = OpenAI()
df = SmartDataframe('../__data/Amazon_Sales_Report.csv', config={"llm": llm, 'verbose':True})

# %%
df.chat("How many columns and rows")
# Out:
# {'type': 'string', 'value': 'The DataFrame has 128988 rows and 21 columns.'}
# 'The DataFrame has 128988 rows and 21 columns.'

# %%
df.chat("what is this df about?")
# Out:
# 'The DataFrame contains 128988 total orders, with 109706 shipped and 658 pending orders. Total sales amount is 78594665.24999997.'

# %%
df.chat("what is this df about?")
